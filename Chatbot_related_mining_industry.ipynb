# %% [markdown]
# <a href="https://colab.research.google.com/github/hareram14/Chatbot-Realated-Mining-Industry/blob/main/Chatbot_related_mining_industry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 457.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 7.9 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer

# Sample dataset of mining-related Acts, Rules, and Regulations
mining_data = {

"Explosive act(1884)" : "An Act to regulate the manufacture, possession, use, sale,transport, import and export of explosives came to force in  26th February, 1884",
"explosive act Implemented in" :  "This Act has been in force in the Districts of Hazaribagh, Lohardaga (now called the Ranchi District) Palamau and Manbhum and in Pargana Dhalbhum and the K.olhan in the Singhbhum District of the Chota Nagpur Division." ,
"Modifications of the explosive Act when extended to Goa, Daman and Diu, Dadra and Nagar Haveli, and Lakshadweep" : "* Extension to Goa, Daman, and Diu - The Explosives Act was extended to the Union territories of Goa, Daman, and Diu with certain modifications. These modifications could include adjustments to the Acts provisions to better suit the local conditions and requirements of these regions. This extension and modification were made through Regulation 12 of 1962. * Extension to Dadra and Nagar Haveli - The Explosives Act was also extended to the Union territory of Dadra and Nagar Haveli. This extension was made through Regulation 6 of 1963.The Acts extension to Dadra and Nagar Haveli was brought into force on July 1, 1965. This means that the Explosives Act became applicable and enforceable in Dadra and Nagar Haveli from that date onwards. * Extension to Lakshadweep: - Additionally, the Explosives Act was extended to the entire Union territory of Lakshadweep. This extension was made through Regulation 8 of 1965, along with certain modifications. Again, these modifications likely adapted the Act to the unique circumstances of the Lakshadweep region." ,
"Implementation of the explosive act in Pondicherry" :  "The Explosives Act became effective in Pondicherry on October 1, 1963, through Regulation 7 of 1963, Section 3, and Schedule I.",
"Ammonium nitrate an explosive " : "Vide Notification No. G.S.R. S.O. 1678(E) dated 21/07/2011, Ammonium Nitrate having the chemical formula NH4NO3 or any combination containing more than 45 percent of ammonium nitrate by weight including emulsions, suspensions, melts or gels (with or without inorganic nitrates) shall be deemed to be an explosive under the meaning of the Explosives Act 1884. Provided that such ammonium nitrate or any combination thereof shall not include those fertilizers from which ammonium nitrate cannot be extracted by any physical or chemical means.",
"Rules to obtain the license for ammonium nitrate" : "Manufacture, conversion, stevedoring and bagging, import, export, transport, possession for sale or use of Ammonium Nitrate is covered under Ammonium Nitrate Rules, 2012 framed under the Explosives Act, 1884. For manufacture of Ammonium Nitrate an Industrial licence is required under the IDR Act, 1951. A license under the Ammonium Nitrate Rules, 2012 is also required for any of the activities mentioned above.",
"Objective of explosive act 1884" : "The objective of the Explosives Act, 1884 was to regularize the hazardous licensed premises dealing with commercial explosives for public safety but the objective of the Explosives Substance Act, 1906 was to penalize.",
"Categories of explosives in explosive act" : "explosives are divided into four categories according to the risks which they present when initiated, namely – i) Category ‘X’ - Those explosives, which have a fire or a slight explosion risk or both but the effect of which will be local. ii) Category ‘Y’ - Those explosives which have mass fire risk or a moderate explosion risk but not the risk of mass explosion. iii). Category ‘Z’’ – Those explosives which have a mass explosion risk and minor missile effect. iv) Category ‘ZZ’ – Those explosives which have a mass explosion risk and major missile effect If any question arises as to whether any explosives belongs to category x, category y, category – z or category – zz, the matter shall be referred to the Chief Controller of Explosives, whose decision shall be final." ,
"Section 5 of explosive act 1884" : "Power to make rules as to licensing of the manufacture, possession, use, sale, transport and importation of explosives. 5A. Persons already in business in respect of certain explosives to carry on such business without licence for a certain period.",
"Section 7 of explosive act 1884" : "Restriction on trial of offences. [8th June, 1908.] An Act further to amend the law relating to explosive substances.",
"Section 18 of explosive act 1884" : "An authority making rules under this Act shall, before making the rules, publish a draft of the proposed rules for the information of persons likely to be affected thereby." ,
"Purpose of extending the explosive act to various Union territories and regions with modifications" : "The purpose of extending the Explosives Act to different regions with modifications is to tailor the application of the Act to the specific needs and conditions of those areas. Modifications may address local concerns or conditions while maintaining the core safety and regulatory principles of the Explosives Act." ,
"Amendments made by Act 32 of 1978,including the substitution of transport and importation " : "Act 32 of 1978 substituted the phrase transport and importation with some other wording in the Explosives Act, effective from March 2, 1983.",
"Explain term perscribed in explosives act" : "According to the Explosives Act, prescribed means specified or defined by rules made under the Act. These rules provide additional details and specifics about how the Act is implemented and enforced." ,
"Authority to make rules for licensing explosives in India" : "The Central Government has the power to make rules for licensing explosives in India." ,
"Authority of  Central Government to regulate or prohibit concerning explosives": "The Central Government can regulate or prohibit the manufacture, possession, use, sale, transport, import, and export of explosives or any specified class of explosives.",
"Rules under section 5 in explosive act" : "Rules can provide for matters such as the authority granting licenses, fees for licenses, application requirements, license conditions, license duration, appeals authority, and more.",
"Explosives-related business without a license" : "A person can continue their explosives-related business without a license for a certain period if they were carrying on such business immediately before the commencement of the Indian Explosives (Amendment) Act, 1978, and no license was required for that explosive before the amendment. This period is either three months from the commencement date or until the final disposal of their license application, whichever is later." ,
"provision for exemptions in explosive act" : "The Central Government may by notification in the Official Gazette exempt, absolutely or subject to any such conditions as it may think fit to impose, any explosive and 5[any person or class of persons from all or any of the provisions of this Act or the rules made thereunder.",
"Purpose of  regulating explosives through licensing" :  "The purpose of regulating explosives through licensing and rules is to ensure safety, security, and control over the manufacturing, possession, use, sale, transportation, import, and export of explosives. This helps prevent accidents, misuse, and unauthorized handling of dangerous materials." ,
"Person responsible for enforcing these rules and overseeing explosives-related activities" : "The enforcement of these rules and oversight of explosives-related activities may involve multiple authorities, including government agencies responsible for public safety, such as the Chief Controller of Explosives or other designated officers." ,
"Persons already in business in respect of certain explosives to carry without license": "Persons already in business in respect of certain explosives to carry on such business without licence for a certain period.—Notwithstanding anything in section 5 or in the rules made thereunder where, immediately before the commencement of the Indian Explosives (Amendment) Act, 1978 (32 of 1978), any person was carrying on the business of manufacture, sale, transport, import or export of any explosive (for which no licence was required under this Act before its amendment by the Indian Explosives (Amendment) Act, 1978, then, such person shall be entitled to continue to carry on such business without licence in respect of such explosive— (a) for a period of three months from the date of such commencement; or (b) if before the expiry of the said period of three months, such person has made an application for grant of licence under this Act for such business in such explosive, until the final disposal of his application." ,
"Individuals appealling decisions related to explosives licensing" : "Yes, there is provision for appeals. Section (ee) of the text mentions the authority to which appeals can be preferred under section 6F. The rules are expected to outline the procedure for appealing decisions, the time frame within which appeals must be filed, and any associated fees." ,
"Significance of the amendment mentioned in section 5A explosive act": "Section 5A discusses an amendment in the Indian Explosives Act that allows individuals who were already engaged in certain explosives-related businesses before the mentioned amendment to continue their operations for a specific period without obtaining a license. This provision provides a transition period for existing businesses to comply with the new licensing requirements." ,
"Applying for a license to deal with explosives" : "The rules, as mentioned in the text, are expected to specify the manner in which applications for licenses must be made and the details that must be included in these applications. Applicants would need to follow the procedures outlined in these rules when applying for a license.",
"Types of permitted explosives" : "In India, three types of permitted explosives, namely (i) permitted (ordinary) or P1 explosive (ii) permitted (equivalent to sheathed) or P3 explosive (iii) permitted (for solid blasting) or P5 explosive, are commonly manufactured and approved for use in underground coal mines.",
"Non permitted explosives": "Non Permitted Emulsion Explosives are manufactured in various sized cartridges, mainly used in well digging, tunneling, dam construction, metal/mineral mining, both underground and opencast.We manufacture a variety of these explosives: Type Trade Name. Weight Strength. Density g/cc.",
"Section 6 of the Indian Explosives Act " : "Section 6 of the Indian Explosives Act discusses the power of the Central Government to prohibit the manufacture, possession, or importation of specially dangerous explosives. It empowers the Central Government to issue notifications in the Official Gazette to prohibit or regulate such explosives for public safety reasons.",
"Circumstance with which central government can prohibit certain explosive" : "The Central Government can prohibit, either absolutely or subject to conditions, the manufacture, possession, or importation of explosives that it deems to be of a particularly dangerous character and considers it necessary for public safety.",
"Role of the Customs Act, 1962, in relation to explosives importation " : "The Customs Act, 1962, applies to explosives importation when a notification is issued under Section 6 of the Indian Explosives Act. It regulates the importation of explosives in a manner similar to how it governs the importation of prohibited or regulated articles.",
"Section 6A of the Indian Explosives Act ": "Section 6A of the Indian Explosives Act discusses the prohibition of manufacture, possession, sale, or transport of explosives by young persons and certain other individuals. It outlines specific criteria that disqualify individuals from engaging in explosives-related activities.",
"License authority and its responsibility under section 5B" : " The licensing authority is the entity responsible for granting licenses under Section 6B. It has the authority to grant or refuse licenses for explosives-related activities, based on criteria such as technical expertise and good reason for obtaining a license.",
"Circumstances under which licensing authority refuse to grant a license under Section 6C " : " The licensing authority can refuse to grant a license if it is required for a prohibited explosive, if the applicant is prohibited by law from handling explosives, if the applicant is of unsound mind, or if public safety or peace necessitates the refusal.",
"Additional conditions that can be imposed on licenses under Section 6D" : "Section 6D allows the licensing authority to impose conditions on licenses in addition to prescribed conditions. These additional conditions can be tailored to specific cases as deemed necessary by the licensing authority.",
"Authority who can suspend or revoke a license under Section 6E" : "The licensing authority can suspend or revoke a license under Section 6E. It can do so for reasons such as violations of license conditions, security concerns, mental health issues, or providing false information during the license application process. Courts can also suspend or revoke licenses upon conviction for offenses related to explosives.",
"Appeals against the decisions made by the licensing authority" : "Yes, individuals aggrieved by decisions of the licensing authority, such as refusal to grant a license or suspension/revocation of a license, can appeal to an appellate authority. The appeal process is outlined in Section 6F, and there are provisions for the timing of appeals and fees.",
"Finality of the decisions made by the appellate authority under Section 6F": "Decisions made by the appellate authority under Section 6F are final and binding unless otherwise directed. Appeals cannot be made against orders made by or under the direction of the Central Government.",
"Section 6 of the Indian Explosives Act" : "The purpose of Section 6 is to grant the Central Government the authority to regulate and control the manufacture, possession, and importation of particularly dangerous explosives to ensure public safety." ,
"Circumstances under which the Central Government can prohibit the manufacture, possession, or importation of explosives" : "The Central Government can prohibit explosives manufacture, possession, or importation when it deems an explosive to be of such dangerous character that it's necessary for public safety. This can be done through notifications published in the Official Gazette." ,
"The Central Government determine which explosives are specially dangerous": "The determination of whether an explosive is specially dangerous is based on the discretion and assessment of the Central Government. There may be specific criteria or factors considered, but these are not detailed in the text.",
"Significance of Section 6B in the Indian Explosives Act" : "Section 6B outlines the process for granting licenses for explosives-related activities. It specifies the criteria that the licensing authority should consider when granting licenses." ,
"Who can apply for a license under Section 6B" : "Individuals or entities can apply for a license under Section 6B for the purpose of manufacturing explosives if they possess technical knowledge and experience or can employ individuals with such expertise. For other purposes, a license may be granted if the applicant has a good reason for obtaining it.",
"Power of licensing authority have regarding license conditions" : "The licensing authority has the power to impose additional conditions in licenses beyond the prescribed ones if it deems them necessary for a specific case.",
"The grounds for the suspension or revocation of a license under Section 6E" : "A license can be suspended or revoked if the holder is prohibited by law from dealing with explosives, is of unsound mind, is deemed unfit for a license, has violated license conditions, or has failed to comply with a notice to surrender the license.",
"Person who can suspend or revoke a license under Section 6E, apart from the licensing authority" :"Apart from the licensing authority, a court can suspend or revoke a license if the holder is convicted of an offense under the Explosives Act or its rules. This can also be done by an appellate court or the High Court during the exercise of its revision powers.",
"Role of the Central Government in suspending or revoking licenses under Section 6E" : "The Central Government has the authority to suspend or revoke, or direct any licensing authority to suspend or revoke, all or any licenses granted under the Explosives Act throughout India or in specific parts of the country.",
"Appealing against decisions made by the licensing authority regarding licenses" : "Yes, individuals who are dissatisfied with decisions made by the licensing authority, such as the refusal to grant a license or the suspension/revocation of a license, can appeal to an appellate authority as outlined in Section 6F.",
"State of order of suspension or revocation under Section 6F during the appeal process" : "Unless the appellate authority directs otherwise, the order of suspension or revocation remains in force during the appeal process. However, it can be conditionally or unconditionally altered by the appellate authority.",
"Role of the Central Government in relation to explosives regulation under the Indian Explosives Act" : "The Central Government has the authority to make regulations, including prohibiting certain explosives, issuing notifications for public safety, and overseeing the importation of explosives under Section 6 of the Act.",
"Official Gazette refer to in the context of Section 6": "The Official Gazette is a government publication where official notices, notifications, and regulations are published. Notifications regarding the prohibition or regulation of explosives, as mentioned in Section 6, are published in the Official Gazette to make them legally binding.",
"Section 6A of the Indian Explosives Act impact the possession and handling of explosives by certain individuals" : "Section 6A prohibits specific individuals, such as those under the age of eighteen, individuals with certain criminal convictions, or those who have had their licenses canceled, from manufacturing, selling, transporting, importing, exporting, or possessing explosives as specified by the Central Government.",
"Significance of Section 6D regarding the imposition of conditions on licenses" : "Section 6D allows the licensing authority to impose conditions on licenses beyond the prescribed ones when it deems them necessary in specific cases. This provides flexibility to tailor license conditions to the unique circumstances of each applicant.",
"Section 6E addressing the suspension and revocation of licenses" : "Section 6E outlines the authority to suspend or revoke licenses, primarily vested in the licensing authority. Courts can also suspend or revoke licenses upon conviction of the holder for explosives-related offenses. The Central Government may issue orders for the suspension or revocation of licenses nationwide or in specific regions.",
"Role of the appellate authority mentioned in Section 6F" : "The appellate authority is responsible for reviewing appeals filed by individuals aggrieved by decisions of the licensing authority, such as license refusals or suspensions/revocations. It has the power to confirm, modify, or reverse these decisions based on the merits of the case." ,
"Time limit for filing appeals under section 6F" : "Yes, there is a prescribed time limit for filing appeals, and they must be filed within that period. However, the appellate authority may admit appeals filed after the expiry of the time limit if the appellant can demonstrate sufficient cause for the delay.",
"Significance of the provision stating that no appeal shall lie against an order made by, or under the direction of, the Central Government": "This provision means that certain decisions or orders made directly by the Central Government are not subject to appeal. It underscores the Central Government's authority in specific matters related to explosives regulation." ,
"Decisions of the appellate authority be challenged further in higher courts " : "The text does not explicitly mention further challenges in higher courts, but it does state that decisions made by the appellate authority are final unless directed otherwise. It's possible that individuals may have other legal avenues to pursue if they disagree with the appellate authority's decision, but those would depend on the broader legal framework." ,
"Section 7 of the Indian Explosives Act address" : "Section 7 of the Indian Explosives Act empowers the Central Government to create rules that authorize officers to perform various actions related to inspection, search, seizure, detention, and removal of explosives or places where explosives are handled.",
"Authority to make rules under Section 7" : "The Central Government is granted the authority to make rules under Section 7. These rules are expected to be consistent with the provisions of the Explosives Act.",
"Powers conferred upon officers under section 7"  : "The rules made under this section can authorize officers, either by name or in virtue of their office, to perform several actions, including entering and inspecting places where explosives are handled, searching for explosives, taking samples of explosives, and seizing, detaining, or removing explosives or their ingredients if necessary.",
"Circumstances with which an officer can exercise the powers of section 7" : "Officers can exercise these powers when explosives are being manufactured, possessed, used, sold, transported, imported, or exported under a license granted under the Explosives Act. They can also use these powers if they have reason to believe that explosives are being handled in violation of the Act or its associated rules." ,
"Significance of the provision related to taking samples of explosives" : "This provision allows authorized officers to take samples of explosives found during inspections. They must pay the value of the samples they take. This is typically done to check the quality and compliance of the explosives with the Act and its rules.",
"Actions can an officer take after seizing explosives under the section 7" : "An officer can seize, detain, and remove any explosive or its ingredients found during inspections. If deemed necessary, they can also destroy such explosives or ingredients.",
"Relation between the provisions of the code of the criminal procedure and the search conducted by officers authorized under section 7" : "The provisions of the Code of Criminal Procedure, 1973, which relate to searches, are applicable to searches conducted by officers authorized under rules made under Section 7. This means that certain legal procedures and safeguards applicable to searches are also relevant in these situations.",
"Primary objective of Section 7 of Indian Explosives act" : "The primary objective of Section 7 is to grant the Central Government the authority to create rules that empower designated officers to oversee and regulate the handling of explosives to ensure compliance with the Act and public safety.",
"Officers mentioned in Section 7" : "Officers referred to in Section 7 can be authorized either by name or based on their official positions. The Central Government establishes rules that grant them these powers.",
"Circumstances with which an officer can enter and inspect a place where explosives are handled" : " An officer can enter and inspect any place, including aircraft, carriages, vessels, or other locations where explosives are being manufactured, possessed, used, sold, transported, imported, or exported under a license granted under the Explosives Act. They can also enter if they have reason to believe that explosives are being handled in violation of the Act or its rules.",
"Action of an officer during an inspection" : "During an inspection, an officer can search for explosives, take samples of explosives found therein (with payment), and seize, detain, remove, and if necessary, destroy any explosives or their ingredients found at the location.",
"Necessity of samples explosives during inspections" : "Taking samples of explosives during inspections is a quality control measure. It allows authorities to assess the compliance and safety of the explosives being handled, ensuring that they meet the required standards and do not pose risks.",
"Legal provisions that is applied to searches conducted by officers authorized under Section 7" : "Searches conducted by officers authorized under Section 7 are subject to the provisions of the Code of Criminal Procedure, 1973, to the extent that they are applicable. This means that the legal procedures and safeguards for searches provided in that code would apply to these searches.",
"Significance of the provision allowing the destruction of explosives if necessary" : "The provision allowing the destruction of explosives is crucial for public safety. If explosives are found to be unsafe, hazardous, or in violation of the law, authorities can take immediate action to remove and, if required, destroy them to prevent potential accidents or harm.",
"Refuse to the Entry of authorized officers during inspections" : "Individuals or entities handling explosives under the Explosives Act are typically required to cooperate with authorized officers during inspections. Refusal to cooperate may have legal consequences, including potential penalties.",
"Main purpose of Section 8 of the Indian Explosives Act" : "The main purpose of Section 8 is to establish a legal requirement for individuals or entities handling explosives, as well as those in charge of aircraft, carriages, or vessels carrying explosives, to report accidents involving explosions, fires, and resulting loss of life or serious injuries.",
"Person who is obligated to give notice of accidents as per section 8" : "The obligation to give notice of accidents under Section 8 applies to: - The occupier of a place where explosives are manufactured, possessed, or used. - The master of an aircraft or vessel carrying explosives. - The person in charge of a carriage transporting explosives." ,
"Types of accidents must be reported under Section 8" : "Section 8 requires the reporting of accidents that involve explosions or fires and are attended by the loss of human life or serious injury to persons or property. These are typically accidents of a significant and hazardous nature.",
"Specific timeframe for reporting accidents under Section 8" : "Section 8 mentions that accidents must be reported within such time and in such manner as may be by rule prescribed.This means that the specific timeframe and reporting procedures may be established in rules associated with the Explosives Act.",
"Person to whom the accidents be reported under Section 8" : " Accidents must be reported to: - The Chief Controller of Explosives. - The officer in charge of the nearest police station." ,
"The role of the Chief Controller of Explosives" : "The Chief Controller of Explosives is a key authority responsible for overseeing and regulating explosives-related matters. In the context of Section 8, they are one of the recipients of accident reports, and their role may include further investigation or action as necessary." ,
"Why is it important to report accidents involving explosives promptly" : "Prompt reporting of accidents involving explosives is essential for public safety and regulatory compliance. It allows authorities to assess the situation, investigate the causes, and take appropriate measures to prevent further accidents and ensure the safe handling of explosives." ,
"Legal consequences for failing to report accidents under Section 8" : "The section does not explicitly state legal consequences for failure to report accidents. However, non-compliance with legal requirements could potentially result in penalties or legal actions, depending on the circumstances and applicable regulations.",
"Section 9 of the Indian Explosives Act ": "The primary purpose of Section 9 is to establish procedures for conducting inquiries into accidents involving explosives. These inquiries are conducted to determine the causes of such accidents." ,
"Inquiry required under Section 9": "Section 9 mandates an inquiry in two situations: - When an accident involving explosives occurs in or about any place, aircraft, carriage, or vessel under the control of the Armed Forces of the Union. - In other circumstances, a District Magistrate (or a subordinate Magistrate designated by the District Magistrate) may conduct an inquiry if the accident results in loss of human life. In other cases, it's discretionary.",
"conducting inquiries under Section 9" : "In cases involving the Armed Forces of the Union, the respective naval, military, or air force authority conducts the inquiry. In other circumstances, a District Magistrate or a subordinate Magistrate may conduct the inquiry.",
"Powers of the persons conducting the inquiry have under Section 9" : "The persons conducting the inquiry have all the powers of a Magistrate as per the Code of Criminal Procedure, 1973. Additionally, they may exercise powers conferred on any officer by rules under Section 7 if necessary for the inquiry.",
"Outcome of the inquiry conducted under Section 9" : "The person conducting the inquiry is required to prepare a report detailing the causes of the accident and its circumstances. This report is submitted to the Central Government.",
"Central Government making rules related to inquiries under Section 9" : "Yes, the Central Government is empowered to make rules to regulate the procedure of inquiries under this section. These rules may cover various aspects of the inquiry process.",
"Purpose of inquiries under Section 9A" : "Section 9A allows the Central Government to order inquiries of a more formal character into accidents similar to those mentioned in Section 8. These inquiries may involve the appointment of the Chief Controller of Explosives or another competent person, along with assessors possessing legal or special knowledge.",
"Inquiries under Section 9 when Section 9A is invoked" : "When the Central Government orders an inquiry under Section 9A, it may direct the discontinuation of any inquiries under Section 9 that are pending at that time.",
"powers of persons conducting inquiries under Section 9A" : "Persons conducting inquiries under Section 9A have extensive powers, including those of a Civil Court under the Code of Civil Procedure, 1908. These powers are used to enforce the attendance of witnesses and compel the production of documents and evidence.",
"Provision for publishing reports of inquiries conducted under Section 9A" : "Yes, the Central Government is required to publish reports of inquiries conducted under Section 9A. These reports are made public at the discretion of the Central Government.",
"Main purpose of Section 9B of the Indian Explosives Act" : "The primary purpose of Section 9B is to define and prescribe penalties for certain offenses related to explosives, including the manufacture, import, export, possession, use, sale, transport, and violations of rules and licenses.",
"Penalties for offenses under Section 9B" : "Section 9B prescribes different penalties for various offenses: - Manufacturing, importing, or exporting explosives in contravention of rules or license conditions can result in imprisonment for up to three years, a fine of up to five thousand rupees, or both. - Possessing, using, selling, or transporting explosives in contravention of rules or license conditions can lead to imprisonment for up to two years, a fine of up to three thousand rupees, or both. - Violations not falling into the above categories can result in a fine of up to one thousand rupees.",
"Additional penalties for violations related to the importation of explosives by water or air " : "Yes, for violations related to the importation of explosives by water (vessel) or air (aircraft), the owner and master of the vessel or aircraft, in the absence of a reasonable excuse, can each be punishable with a fine of up to five thousand rupees." ,
"If a person fails to give notice of an accident as required by Section 8" : "Failure to provide notice of an accident, as required by Section 8, can result in a penalty: - A fine of up to five hundred rupees. - If the accident is attended by loss of human life, the penalty can include imprisonment for up to three months, a fine, or both.",
"Company be held liable for an offense under the Indian Explosives Act" : "A company can be held liable for an offense under the Act if it is proved that the offense was committed with the consent or connivance of, or is attributable to neglect on the part of, any director, manager, secretary, or other officer of the company.",
"Liability of individuals within a company for offenses committed by the company " : "Individuals in charge of, or responsible for, the conduct of the company's business at the time the offense was committed may also be deemed guilty of the offense. They can be proceeded against and punished accordingly.",
"Conditions under which an individual within a company can avoid liability for an offense" : "An individual within a company can avoid liability if they prove that the offense was committed without their knowledge, and they exercised all due diligence to prevent the commission of such offense." ,
"Term company according to  Section 9C"  : "In Section 9C, company refers to any body corporate and includes a firm or other association of individuals." ,
"Section 10 of indian explosive act" : "Section 10 deals with the forfeiture of explosives, explosive ingredients, substances, or any part thereof when a person is convicted of an offense under this Act or its rules.",
"the court ordering the forfeiture of explosives or related items" : "The court can order the forfeiture of explosives, explosive ingredients, substances, or related items when a person is convicted of an offense under this Act or its rules.",
"Section 12 of Indian explosives act ": "Section 12 addresses abetment and attempts to commit offenses punishable under the Act or its rules.",
"Punishments for the individuals under the section 12" : "Individuals who abet or attempt to commit offenses under the Act can be punished as if they had committed the offense itself.",
"Section 15 of the Indian Explosives Act" : "Section 15 ensures that the provisions of the Arms Act, 1959, are not affected by the Explosives Act. It specifies that the Arms Act provisions continue to apply.",
"Conditions with which an authority grant a license under the Explosives Act that also has the effect of a license under the Arms Act" : "An authority can grant a license under the Explosives Act that also has the effect of a license under the Arms Act if empowered to do so by the rules under which the license is granted.",
"Section 16 impact liability under other laws" : "Section 16 clarifies that nothing in the Explosives Act or its rules prevents a person from being prosecuted under any other law for acts or omissions that constitute an offense under the Explosives Act or rules. However, a person cannot be punished twice for the same offense.",
"Section 17 of the Indian Explosives Act" : "Section 17 empowers the Central Government to declare, through notification in the Official Gazette, that substances dangerous to life or property due to their explosive properties or manufacturing processes shall be deemed explosives under the Act, subject to specified exceptions, limitations, and restrictions.",
"Procedure for making, publishing, and confirming rules under Section 18 of the Act" : "The authority making rules under this Act must follow a specific procedure: - Publish a draft of the proposed rules for public information. - Specify a date for consideration of the draft. - Receive and consider objections or suggestions from the public. - The rule will not take effect until published in the Official Gazette. - Publication in the Official Gazette is conclusive evidence of its making.",
"Situation if both Houses of Parliament agree to modify or annul a rule made under this Act" : "If both Houses of Parliament agree to modify or annul a rule made under this Act, the rule will have effect only in the modified form or be of no effect, without affecting the validity of anything previously done under that rule.",
"the objective The Mines Act 1952" :"Aims to regulate the working conditions of mine workers, ensure their safety, and promote their health in mines.",
"The Mines Act, 1952 became operational " : "The Mines Act, 1952 became operational on July 1, 1952.",
"the applicability of the Mines Act  in terms of the number of employees" : "The act does not apply when mining is done for discovery purposes, provided that the number of employees employed is not more than 20 people.",
"mine defined in mines act, 1952" : "Section 2(1)(j) of the Mines Act defines a mine as any excavation for searching or obtaining minerals, including borings, shafts, opencast workings, conveyors, workshops, and more.",
"Responsibilities of owners agents, and managers of mines" : "They are responsible for taking suitable steps in adherence to rules, regulations, and orders related to mining operations, safety, and health.",
"Requirement for drinking water in a mine" : "Every mine must provide and maintain a sufficient supply of drinking water at suitable points for workers.",
"Conservancy of mines in mines act" : "It specifies that there must be a sufficient number of separate latrines and urinals for both males and females, which must be adequately lit, ventilated, and maintained in a clean and sanitary condition." ,
"Medical appliances in mines" : "First aid boxes must be provided in every mine and be readily accessible during all working hours. Mines with 150 or more employees must have a first-aid room.",
"relevant authorities be informed about accidents in a mine" :"Relevant authorities must be informed in case of the occurrence of any accident, bodily injury, fire outbreak, or influx of inflammable or noxious gases in the mine.",
"Diseases reported to relevant authorities under the Mines Act, 1952" : "Relevant authorities must be informed if a person employed in a mine contracts any disease relating to mining operations.",
"Objective of Chapter VI of mines act" : "Chapter VI deals with hours and limitations of employment in mines, aiming to regulate working hours and conditions for mine workers." ,
"Maximum number of working days a person can work in a mine in a week as per Section 28 ,Mines Act,1952" : "A person cannot work in a mine for more than six days in any week.",
"Compensatory rest provided to a mine employee according to Section 29" : "A mine employee deprived of any weekly day of rest must be allowed to rest for the extra work done within two months.",
"Maximum weekly working hours for 18 years working above ground (Section 30) " : "Persons above 18 years working above ground in a mine are not allowed to work for more than 48 hours in a week or for more than nine hours in a day.",
"Overtime wages Section 33" : "Section 33 states that if a person works above ground for more than nine hours in a day or below ground for more than eight hours in a day, they are entitled to wages at twice the rate.",
"Prohibition regarding employment Section 34" : "A person who has worked in a mine within the preceding 12 hours of their duty must not be allowed or required to work further.",
"Maximum daily hours of work including overtime as per section 35 ": " Any person employed in a mine is not allowed to work for more than ten hours in a day, inclusive of overtime.",
"Can women be employed in a mine Section 46" : "Women can be employed in a mine between the hours of 6 A.M. and 7 P.M., either below ground or above ground.",
"Information included in the register of persons Section 48" : "The register must contain the name, age, sex, and nature of work, among other details, of the mine's employees.",
"Purpose of Chapter IV of the Mines Rules" : "Chapter IV deals with Certifying Surgeons and outlines their powers and duties in relation to mine workers' health examinations.",
"Duty of owner, agent or manager concerning Certifying Surgeons rule 23" : "They must afford the Certifying Surgeon all reasonable facilities for carrying out inspection, examination, or inquiry in the mine.",
"Certifying Surgeon after a medical examination Rule 24" : "The Certifying Surgeon must provide the age and fitness certificate to the manager of the mine and carry out examinations upon request by the Chief Inspector or Inspector.",
"Initial medical examinations  conducted in a mine Rule 29-B" : "Initial medical examinations must be conducted for every person employed in the mine within a period of five years.",
"Conducts the medical examination of persons employed or to be employed in mines Rule 29-C" : "The medical examination is carried out by a Medical Officer appointed for the mine or employed by the mine owner.",
"Notice requirement for a medical examination Rule 29-C" : "The manager of the mine must provide at least 20 days' prior written notice to the person to be examined before a medical examination.",
"How many days of rest are allowed in a week under the Mines Act" : "A person cannot work in a mine for more than six days in any week as per Section 28.",
"compensatory days of rest and when are they granted" : "Compensatory days of rest are granted to mine employees who are deprived of their weekly days of rest due to work duties. These compensatory days must be given within two months.",
"maximum weekly working hours for adults working above ground in a mine" : "Adults (above 18 years of age) working above ground in a mine are not allowed to work for more than 48 hours in a given week as per Section 30.",
"the requirement for a weekly day of rest for those working night shifts" : "A weekly day of rest is mandatory for all people working night shifts, and it must be not less than 24 consecutive hours beginning when the shift ends (Section 32).",
"Extra wages for overtime granted under the Mines Act" : "Extra wages for overtime are granted when a person works above ground for more than nine hours in a day or works below ground for more than eight hours in a day, and they are entitled to wages at twice the rate (Section 33).",
"Limitation on daily hours of work in mines" : "Any person employed in a mine is not allowed to work for more than ten hours in a day, inclusive of overtime, as per Section 35.",
"Restrictions regarding women employment in mines under the Mines Act" : "No woman can be employed in any part of a mine, whether below ground or above ground, except between the hours of 6 A.M. and 7 P.M. (Section 46).",
"Information maintained in the register of persons employed in mines" : "Employers must maintain a register containing the name, age, sex, and nature of work among other details of its employees (Section 48).",
"Purpose of Chapter IV of the Mines Rules" : "Chapter IV of the Mines Rules, 1955 deals with Certifying Surgeons and outlines their powers and duties in relation to medical examinations of mine workers.",
"Short title of the Mines Rules 1955" : "The short title of the Mines Rules, 1955 is -Mines Rules,1955-.",
"The Act refer to the rules" : "The Act refers to the Mines Act, 1952 - (35 of 1952).",
"definition of Manager as per these rules": "The definition of Manager includes the Mine Superintendent who is appointed by the owner or agent of a mine under section 17 of the Act and is responsible for the control, management, supervision, and direction of a mine.",
"Calendar year in the rules": "Calendar year means a year from the first day of January to the thirty-first day of December.",
"Quantity of drinking water in a mine according to the Mines Act" : "At least two litres of drinking water for every person employed at any one time should be provided.",
"Inspector require drinking water to be effectively cooled" : "An Inspector can require drinking water to be effectively cooled if 100 persons or more are employed at any one time.",
"Charge for drinking water supplied in a mine" : "No, no charge should be made for the drinking water supplied in a mine.",
"Drinking water stored if not provided from a constant water supply system" : "Drinking water should be kept cool in suitable vessels sheltered from the weather, and these vessels should be emptied, cleaned, and refilled every day.",
"water from a non-public source is fit for human consumption" : "A competent health authority or analyst can provide a certificate regarding the fitness of water from a non-public source for human consumption.",
"final decision in case of a dispute regarding water supply arrangements" : "The decision of the Chief Inspector is considered final in case of a dispute regarding water supply arrangements.",
"standards for providing latrine accommodation in a mine based on the mentioned rules" : "The standards for providing latrine accommodation in a mine are at least one seat for every 50 males and at least one seat for every 50 females employed at one time.",
"Materials used to construct latrines in a mine" : "Latrines in a mine should be built of brick or other suitable building material.",
"Latrines clean and sanitary" : "Latrines and urinals in or about a mine should be kept in a clean and sanitary condition. Receptacles for night-soil should be cleaned and disinfected at least once every day.",
"qualifications are required for personnel rendering first-aid in a mine" : "Personnel rendering first-aid in a mine should be qualified nurses, dressers, compounder-cum-dressers, or medical practitioners. They should hold a valid first-aid certificate of the standard of St. John’s Ambulance Association (India).",
"First-aid rooms white-washed" : "Interior walls, ceilings, and partitions of first-aid rooms in a mine should be white-washed once at least every four months. If parts are finished with glazed tiles or a smooth polished and impervious surface, they should be washed with suitable detergents and disinfectants at least once every seven days.",
"a person holding a position of supervision or management in a mine" : "Persons holding positions of supervision or management in a mine include managers, undermanagers, electrical and mechanical engineers, overmen, foremen, sirdars, and others as specified in the rules or determined by the Chief Inspector.",
"Compensatory days of rest in a mine" : "Compensatory days of rest are allowed to ensure that employees have adequate rest periods. These days are provided to employees who have not been allowed their weekly day of rest, and they should not be required to work continuously without rest.",
"responsible for arranging training in first-aid and providing first-aid equipment in a mine" : "The owner, agent, or manager of a mine is responsible for arranging training in first-aid and providing the necessary first-aid equipment as prescribed in the rules.",
"latrines and urinals in a mine be cleaned and disinfected" : "Latrines and urinals in a mine should be kept in a clean and sanitary condition, and receptacles for night-soil should be cleaned and disinfected at least once every day.",
"records should the owner, agent, or manager of a mine maintain regarding leave with wages" : "They should maintain a record of leave with wages for every employee in Form G and H.",
"the records of leave with wages be preserved": "The records should be preserved for a period of two years after the last entry has been made.",
"information regarding leave with wages should be exhibited every year" : "On or before the 20th day of February, information regarding leave with wages due to each person employed, calculated up to the 1st January of that year, should be exhibited on the notice board at the office of the mine.",
"Employee's death entitled leave wages due" : "In the event of an employee's death, the leave wages due shall accrue to their legal heirs or nominee.",
"Overtime calculation" : "Overtime should be calculated at the end of each wage period. Fractions of an hour less than 30 minutes should be ignored, and fractions of 30 minutes or more should be counted as one hour.",
"Constructing shelters at mine" : "Shelters should have a floor area of not less than 14 square meters, adequate height, effective protection from the weather, and a supply of cool drinking water during working hours.",
"Canteen provided in mine" : "A canteen is required at a mine where more than 250 persons are ordinarily employed.",
"Canteen construction" : "Canteens should be constructed according to approved plans and specifications, have proper lighting, a washing place for females, be kept clean, and have facilities for garbage disposal.",
"Canteen facilities" : "Canteens should provide sufficient furniture, utensils, equipment, clean clothes for staff, an adequate supply of drinking water, and hot water for cleansing utensils.",
"Canteen staff ": "The canteen is run by the owner, agent, or officer in charge of the canteen, who appoints supervisory and other staff for its proper functioning" ,
"Welfare Officer appointed" : "A Welfare Officer must be appointed for every mine where 500 or more persons are ordinarily employed, and additional Welfare Officers may be required for mines with more than 2500 persons employed.",
"Welfare Officer qualifications" : "A Welfare Officer should have a university degree, a degree or diploma in social science or social work recognized by the government, and preferably three years of practical experience in handling labor problems. They should also know the language of the district or the majority language of the mine's employees.",
"Substitute for welfare officer" : "In case of temporary absence, illness, or similar reasons, the owner, agent, or manager can authorize a competent person in writing to act as a substitute for the Welfare Officer, but such authorization is limited to 30 days without the Chief Inspector's previous consent.",
"Welfare Officer appointment" : "The owner, agent, or manager must send a written notice of every appointment, authorization, discharge, dismissal, resignation, or termination of service of a Welfare Officer, along with the date, to the Chief Inspector within seven days.",
"Primary duties of welfare officer" : "The primary duties of a Welfare Officer in a mine include: - Establishing and maintaining harmonious relations between management and employees. - Addressing employee grievances and seeking their redressal. - Promoting good relations between management and employees for productivity and improved working conditions. - Assisting in the formation of various committees related to work, safety, and welfare. - Providing guidance on leave policies and other employee-related matters. - Advising on welfare provisions and supervising welfare activities. - Suggesting measures to improve the standard of living for workers. - Performing any other duty connected with the welfare of mine employees.",
"Welfare Officer deal with disciplinary cases against mine employees" : "A Welfare Officer should not deal with disciplinary cases against mine employees. They should not appear on behalf of the management in disciplinary cases unless required by a Conciliation Officer, Court, or Tribunal to appear as an independent witness. However, employees can approach the Welfare Officer regarding grievances arising from disciplinary actions against them.",
"Welfare Officers report" : "Every Welfare Officer must keep a record of their day-to-day work and, at the end of each year, forward a summary report of their work during the year to the Chief Inspector through the manager of the mine.",
"Service conditions to a Welfare Officer in a mine ": "A Welfare Officer should be given appropriate status corresponding to the status of other executive heads in the mine. Their conditions of service should be the same as those of other staff members of corresponding status in the mine.",
"Identity tokens issued in mines" : "Identity tokens, also known as tokens, are issued to every person employed in a mine for identification purposes. They help ensure that only authorized individuals enter the mine for work. The tokens are issued free of cost and must be carried by employees during their working hours.",
"languages should the abstracts bye-laws and notices be posted in at a mine" : "The abstracts of the Act, bye-laws, and notices should be posted in English, Hindi, and either the language of the district in which the mine is situated or the language understood by a majority of the persons employed in the mine. The Chief Inspector may specify the language if necessary.",
"Observance of local time" : "The rule requires mines in specific local areas, as specified in the Sixth Schedule, to observe the local mean time specified in the same schedule. It is for the purpose of ensuring uniformity in timekeeping in those areas.",
"prohibition regarding intoxicating drugs and drinks in mines" : "The rule prohibits carrying or permitting the carrying of intoxicating drinks or drugs below ground into mine workings. Additionally, no person employed in or about a mine is allowed to possess, carry, or consume intoxicating drinks or drugs or remain in a state of intoxication or drunkenness during work.",
"fees payable to a medical practitioner for examinations related to occupational diseases": "A medical practitioner conducting examinations in accordance with subsection (2) of section 25 is paid as follows: - Up to rupees sixteen for each clinical examination. - Up to rupees sixteen for each X-ray examination.",
"the rate of disability allowance for occupational diseases as per the rules" : "The disability allowance payable under the first provision to sub-section (5) of section 9A of the Act is at the rate of fifty percent of the monthly wages that the affected individual was receiving immediately before undergoing the medical examination under sub-section (2) of section 9A of the Act.",
"Occupational disease compensation to a person" : "If a person decides to leave their employment in the mine due to an occupational disease, they are entitled to compensation as per the provisions of the Workmen’s Compensation Act, 1923 (8 of 1923). The disease is deemed to be an injury by accident under that Act. If the disease is not covered under Schedule III of that Act, the person shall be paid disability compensation at the same rates as provided under that Act as if it were an injury. The lump-sum compensation payable under this rule shall not be in addition to the compensation payable under the Workmen’s Compensation Act.",
"fees and expenses payable under these rules be paid" : "Fees or other expenses payable by the owner, agent, or manager under these rules should be paid directly into the treasury or a branch of the State Bank of India. The receipt from the treasury or bank should be sent to the Chief Inspector along with the relevant particulars.",
"Appeals process available for orders made by the Inspector" : "Yes, there is an appeals process available. Against an order made by the Inspector under any of these rules, an appeal shall lie to the Chief Inspector. The Chief Inspector may confirm, modify, or cancel the order. The appeal should be preferred within 30 days of the receipt of the order by the appellant.",
"Rescinded rules" : "All rules framed by State Governments under section 30 of the Indian Mines Act, 1923, those contained in Chapters II, III, and VI of the Mysore Gold Mines Rules, 1953, and those issued by the Government of India notification No. S.R.O 2403, dated the 12th July, 1954, are rescinded. However, all acts done, orders issued, and certificates granted or renewed under these rescinded rules, to the extent that they are not inconsistent with the new rules, are deemed to have been done, issued, granted, or renewed under the new rules.",
"rules to apply to gold mines in the State of Mysore" : "The rules contained in Chapters IV and V of the Mysore Gold Mines Rules, 1953, continue to apply to gold mines in the State of Mysore in addition to the new rules.",
"The Colliery Control Order 2000" : "The Colliery Control Order, 2000, is a regulatory order issued by the Government of India under the Essential Commodities Act, 1955." ,
"Issued control order 2000" : "It was issued to regulate and control activities related to coal mining and distribution in India.",
"The Colliery Control Order 2000 came into force" : "The Colliery Control Order, 2000, came into force on the 1st day of January, 2000.",
"coal meaning in colliery control order" : "The term coal in this order includes various forms of carbonaceous matter such as anthracite, bituminous coal, lignite, peat, and coke when sold or marketed as coal.",
"Coal Controller position " : "The Coal Controller is a person appointed by the Central Government under the provisions of the Coal Controller’s Organisation (Group ‘A’ Posts) Recruitment Rules, 1986.",
"colliery defined in colliery control order 2000" : "A colliery is defined as any mine or open working where winning or extraction of coal is the principal objective of the mining, quarrying, or any other operation carried on therein. It also includes plants for the production of coke or washing of coal.",
"Disposal meaning in colliery control order" : "Disposal in this order includes activities like agreeing to dispose of, offering to dispose of, and the actual disposal of ownership or any proprietary interest, the right of possession, and possession, whether or not accompanied by any disposal of ownership or proprietary interest.",
"size in colliery control order" : "The term size in relation to coal follows the specifications provided by the Bureau of Indian Standards in their specification number IS:437-1979.",
"Central Government categorize coal" : "The Central Government may, by notification in the Official Gazette, prescribe the classes, grades and sizes into which coal may be categorised and the specifications for each such class, grade or size of coal.",
"Role of the Coal Controller" : "The Coal Controller is responsible for establishing the procedure and method for sampling and analyzing coal to declare and maintain the grades of coal mined in a colliery based on this categorization.",
"Responsibility of a agent of a colliery regarding the declaration of coal classes": "The agent of a colliery is responsible for declaring the classes, grades, or sizes of the coal found in the colliery according to the procedure specified in sub-clause (1) of the Colliery Control Order, 2000.",
"The Coal Controller ensure the correctness class, grade, or size of coal in a colliery" : "The Coal Controller or any officer authorized by him can inspect the colliery to verify the correctness of the declared class, grade, or size. If necessary, they can draw samples during the inspection, and the owner, agent, or manager of the colliery is obligated to provide reasonable facilities and assistance for this purpose.",
"declared grade of coal in a colliery does not conform to the grade notified under clause 3 of the Colliery Control Order, 2000" :" If, after inspection or based on the samples drawn, the Coal Controller determines that the declared grade does not conform to the grade notified under clause 3, the owner, agent, or manager of the colliery must revise the grade according to the directions issued by the Coal Controller.",
"Disputes regarding the declaration of coal grades resolved" : "Disputes between a consumer and a colliery owner regarding the declaration of coal grades can be referred to the Coal Controller for resolution. The decision of the Coal Controller in such disputes is binding on the colliery owner.",
"Submitting returns and information to the Coal Controller, and who is required to do so" : "Every owner of a colliery and every person engaged in the coal business, when directed by the Coal Controller, must submit returns and other information within the specified time as per the directions given by the Coal Controller.",
"Disposal of coal stocks" : "The Central Government can issue directions to regulate the disposal of coal stocks or expected coal output in a colliery during any period as it deems fit.",
"Quality surveillance and regulation" : "The Coal Controller and authorized officers have the power to adjust coal loading in wagons, trolleys, or trucks in a colliery based on specified procedures and remove impurities. They can also detain wagons, trolleys, or trucks for loading adjustments and return them to the colliery for unloading and reloading as needed.",
"Central Government limit the mining in a colliery": "The Central Government may issue such directions as it may deem fit to any colliery owner prohibiting or limiting the mining or production of any grade of coal and the colliery owner shall comply with such directions.",
"Prior written permission required to open a coal" :" Prior written permission from the Central Government is required for opening a coal mine, seam, or section of a seam in a colliery. This permission is necessary before commencing mining operations.",
"Time limit for resuming mining operations" : "Mining operations in a colliery or seam that has been discontinued for a period exceeding one hundred and eighty days require prior written permission from the Central Government before they can be resumed.",
"notifying the Coal Controller when mining operations in a coal mine or seam are temporarily suspended" : "When mining operations in a coal mine or seam are suspended or closed, whether temporarily or permanently, the owner, agent, or manager of the colliery must provide a notice of such suspension or closure to the Coal Controller within thirty days from the date of suspension or closure.",
"Sub-divide mining unit or operate it as a separate unit without prior permission from the Central Government" :" No, an owner of a colliery or a group of collieries permitted to work as a single mining unit or operating as a single unit at the time of the commencement of this order cannot sub-divide their mining unit or work as a separate unit without prior permission from the Central Government.",
"the Coal Controller and authorized officers have with regards to inspecting collieries" : "The Coal Controller and authorized officers have the power to: Require colliery owners, agents, or managers to provide information related to coal production and the colliery's boundaries. Request the production of documents, registers, and working plans. Inspect mine plans in the possession of the colliery owner, agent, or manager. Enter and inspect any colliery.",
"Powers specified under clauses 6,9 and 11 of the Colliery Control Order 2000 be delegated to the Coal Controller" : "Yes, the powers specified under clauses 6, 9, and 11 can be delegated to the Coal Controller through a notification in the Official Gazette.",
"Provision for exemptions from the regulations in the Colliery Control Order" :" The Central Government has the authority to grant exemptions from the regulations in the Colliery Control Order, 2000, if it deems necessary for avoiding hardship or for other just and sufficient reasons. Such exemptions are granted through a notification in the Official Gazette.",
"the purpose of the Payment of Wages (Mines) Rules, 1956" : "The Payment of Wages (Mines) Rules, 1956 are a set of rules that regulate the payment of wages to workers in the mining industry. The rules are intended to ensure that workers are paid on time and in full, and that they are not subjected to any unfair deductions from their wages.",
"Person who is responsible for implementing these rules in mines" : "The rules are typically enforced by the appropriate government authorities, such as the labour department or mining authorities, in accordance with local regulations.",
"the law specifying regarding the frequency of wage payments in mines" : "The law typically specifies the frequency of wage payments, which is usually at regular intervals not exceeding one month. The exact frequency may vary depending on the mine and local regulations.",
"provisions for deductions from wages in mining rules" : "Yes, the rules often include provisions that regulate permissible deductions from employees' wages. Deductions must comply with the specified limitations and conditions.",
"relationships between disputes and wage payments resolved" : "The rules may outline the procedures for addressing and resolving disputes related to wage payments, including the appointment of authorities or labour inspectors for adjudication.",
"specific rules regarding the maintenance of wage records in mines" : "Yes, the rules typically require mine operators to maintain accurate records of wages, including details of earnings, deductions, and other relevant information.",
"penalties or consequences arising from non-compliance with mining rules" : " Non-compliance with these rules may result in penalties, fines, or legal actions against the mine operator, as specified by the local labor or mining authorities.",
"employees request copies of their wage records under mining rules" :" In many cases, employees have the right to request and obtain copies of their wage records to ensure transparency and accuracy in wage payments.",
"the Payment of Wages Mines Rules 1956 applicable to" :" The Payment of Wages (Mines) Rules, 1956 are applicable to all workers employed in mines, regardless of their wages or salary. This includes workers employed by contractors as well as by mine owners themselves.",
"key provisions of the Payment of Wages Mines Rules 1956" : " The key provisions of the Payment of Wages (Mines) Rules, 1956 include: • Wages must be paid on a working day within 7 days of the end of the wage period (or within 10 days if 1,000 or more persons are employed).  •   Wages must be paid in cash or by cheque.  • No deductions can be made from wages except those authorized under the law.  •  Workers must be given a wage slip for each wage period. ",
"the penalties for violating the Payment of Wages Mines Rules 1956" : " Employers who violate the Payment of Wages (Mines) Rules, 1956 can be fined or even imprisoned.",
"website in which we can get more information about the Payment of Wages Mines Rules, 1956" : " You can get more information about the Payment of Wages (Mines) Rules, 1956 from the website of the Ministry of Labour and Employment, Government of India.",
"wage period" : " A wage period is the period of time for which wages are calculated and paid. Wage periods can be weekly, biweekly, or monthly.",
"the authorized deductions from wages" : " The authorized deductions from wages include: •  Income tax  •   Social security contributions  •    Advances paid to the worker  •  Fines imposed by the employer for specific offenses  •  Deductions for damage to the employer's property caused by the worker's negligence ",
"wage slip" : " A wage slip is a document that shows the details of a worker's wages, including the gross amount earned, the deductions made, and the net amount paid.",
"action to do when employer is violating the Payment of Wages Mines Rules 1956" : " If your employer is violating the Payment of Wages (Mines) Rules, 1956, you can file a complaint with the local labor inspector. The labor inspector will investigate your complaint and take appropriate action against your employer.",
"deductions allowed from wages under these rules" : " Yes, certain deductions are allowed, such as income tax, contributions to provident funds, and deductions for damages or loss caused by the employee's neglect or default. However, total deductions should not exceed 75% of the gross wages.",
"rules regarding the mode of wage payment" : " Wages must be paid either in current coin or currency notes or by check or through electronic transfer to the employee's bank account. Payment in kind is generally not allowed.",
"specific rules related to wage registers and records" : " Yes, employers are required to maintain wage registers and records, which should contain details of wages paid, deductions made, and other relevant information. These records must be preserved for at least three years.",
"penalties are imposed for non-compliance with The Payment of Wages Mines Rules 1956" : " Non-compliance with these rules can lead to penalties, including fines and legal actions against the employer.",
"can employees seek redressal for wage-related issues under these rules" : " Employees can approach the labor authorities or the labour department to seek redressal for wage-related grievances or disputes with their employer.",

}
# Initialize NLTK components
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Function to preprocess text
def preprocess_text(text):
    # Tokenize the text
    words = word_tokenize(text.lower())

    # Remove stopwords and lemmatize words
    words = [lemmatizer.lemmatize(word) for word in words if word.isalnum() and word not in stop_words]

    return " ".join(words)

# Function to find relevant information
def find_information(query):
    query = preprocess_text(query)
    relevant_info = []

    for key, value in mining_data.items():
        if query in preprocess_text(key):
            relevant_info.append(value)

    return relevant_info

# Main chatbot loop
while True:
    user_input = input("User: ")

    if user_input.lower() == 'exit':
        print("Chatbot: Goodbye!")
        break

    responses = find_information(user_input)

    if responses:
        print("Chatbot: Here is some information related to your query:")
        for response in responses:
            print("- " + response)
    else:
        print("Chatbot: I couldn't find any information related to your query.")


app =  gr.Interface(fn = find_information, inputs="text", outputs="text")
app.launch()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# User: What is The Colliery Control Order 2000?
# Chatbot: Here is some information related to your query:
# - The Colliery Control Order, 2000, is a regulatory order issued by the Government of India under the Essential Commodities Act, 1955.
# - The Colliery Control Order, 2000, came into force on the 1st day of January, 2000.
# - A colliery is defined as any mine or open working where winning or extraction of coal is the principal objective of the mining, quarrying, or any other operation carried on therein. It also includes plants for the production of coke or washing of coal.
# ...
